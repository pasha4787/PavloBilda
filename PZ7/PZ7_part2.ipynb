# %% [markdown]
# # Практична робота №3 (частина 2)
# ## Найпростіший потік подій. СМО. Ланцюги Маркова
#
# Варіант **2** → задачі **2 та 3**.

# %%
import numpy as np
import math

# %% [markdown]
# ### Задача 2 – квадрат матриці переходів

# %%
P1 = np.array([[0.4,0.6],[0.3,0.7]])
P2 = P1@P1
P1, P2

# %% [markdown]
# ### Задача 3 – СМО M/M/1/2, λ=2, μ=1

# %%
lam, mu, n = 2.0, 1.0, 2
rho = lam/mu
norm = sum(rho**k for k in range(n+1))
P = [(rho**k)/norm for k in range(n+1)]
P0,P1,P2 = P
P0,P1,P2,sum(P)

# %%
P_busy = 1-P0
A = lam*(1-P2)
w = 0*P0 + 1*P1 + 2*P2
T_obs = 1/mu
T_resp = w*T_obs
P_busy, A, w, T_obs, T_resp
